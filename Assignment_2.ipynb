# %% [markdown]
# <a href="https://colab.research.google.com/github/kohxuan/HPDP_Assignment2/blob/main/Assignment_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
files.upload()  # Upload kaggle.json here
# Out:
#      <input type="file" id="files-2f3cb544-0532-49a5-a655-9e362dc57dae" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2f3cb544-0532-49a5-a655-9e362dc57dae">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets download -d perkymaster/school-donations --unzip
# Out:
# Dataset URL: https://www.kaggle.com/datasets/perkymaster/school-donations
# License(s): unknown
# ...
#  98% 1.25G/1.27G [00:20<00:00, 260MB/s]
# 100% 1.27G/1.27G [00:20<00:00, 66.3MB/s]

# %%
import pandas as pd

df = pd.read_csv("Projects.csv")
df.head()
# Out:
#                          Project ID                         School ID  \
# 0  7685f0265a19d7b52a470ee4bac883ba  e180c7424cb9c68cb49f141b092a988f
# 1  f9f4af7099061fb4bf44642a03e5c331  08b20f1e2125103ed7aa17e8d76c71d4
# 2  afd99a01739ad5557b51b1ba0174e832  1287f5128b1f36bf8434e5705a7cc04d
# 3  c614a38bb1a5e68e2ae6ad9d94bb2492  900fec9cd7a3188acbc90586a09584ef
# 4  ec82a697fab916c0db0cdad746338df9  3b200e7fe3e6dde3c169c02e5fb5ae86
#
#                          Teacher ID  Teacher Project Posted Sequence  \
# 0  4ee5200e89d9e2998ec8baad8a3c5968                               25
# 1  cca2d1d277fb4adb50147b49cdc3b156                                3
# 2  6c5bd0d4f20547a001628aefd71de89e                                1
# 3  8ed6f8181d092a8f4c008b18d18e54ad                               40
# 4  893173d62775f8be7c30bf4220ad0c33                                2
#
#   Project Type                                      Project Title  \
# ...

# %%
df.shape
# Out:
# (1110017, 18)

# %%
import os

file_path = "Projects.csv"
size_bytes = os.path.getsize(file_path)
size_mb = size_bytes / (1024 * 1024)

print(f"Projects.csv file size: {size_mb:.2f} MB")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-f977092bfa24> in <cell line: 0>()
#       2
#       3 file_path = "Projects.csv"
# ----> 4 size_bytes = os.path.getsize(file_path)
#       5 size_mb = size_bytes / (1024 * 1024)
#       6
#
# /usr/lib/python3.11/genericpath.py in getsize(filename)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Projects.csv'

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
# import os

# # Path in your Drive where you want to save the dataset
# drive_path = '/content/drive/MyDrive/datasets/school-donations'

# # Check if folder exists (means dataset already saved)
# if not os.path.exists(drive_path):
#     os.makedirs(drive_path, exist_ok=True)
#     # Download and unzip into your Drive folder
#     !kaggle datasets download -d perkymaster/school-donations --unzip -p {drive_path}
# else:
#     print("Dataset already downloaded in Drive.")
# Out:
# Dataset URL: https://www.kaggle.com/datasets/perkymaster/school-donations
# License(s): unknown
# ...
# 100% 1.27G/1.27G [00:09<00:00, 128MB/s]
# 100% 1.27G/1.27G [00:09<00:00, 146MB/s]

# %%
import pandas as pd

file_path = drive_path + '/Projects.csv'
df = pd.read_csv(file_path)
df.head()
# Out:
#                          Project ID                         School ID  \
# 0  7685f0265a19d7b52a470ee4bac883ba  e180c7424cb9c68cb49f141b092a988f
# 1  f9f4af7099061fb4bf44642a03e5c331  08b20f1e2125103ed7aa17e8d76c71d4
# 2  afd99a01739ad5557b51b1ba0174e832  1287f5128b1f36bf8434e5705a7cc04d
# 3  c614a38bb1a5e68e2ae6ad9d94bb2492  900fec9cd7a3188acbc90586a09584ef
# 4  ec82a697fab916c0db0cdad746338df9  3b200e7fe3e6dde3c169c02e5fb5ae86
#
#                          Teacher ID  Teacher Project Posted Sequence  \
# 0  4ee5200e89d9e2998ec8baad8a3c5968                               25
# 1  cca2d1d277fb4adb50147b49cdc3b156                                3
# 2  6c5bd0d4f20547a001628aefd71de89e                                1
# 3  8ed6f8181d092a8f4c008b18d18e54ad                               40
# 4  893173d62775f8be7c30bf4220ad0c33                                2
#
#   Project Type                                      Project Title  \
# ...
